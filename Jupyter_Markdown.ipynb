# %% [markdown]
# # Nivell 1
#
# ******
# ## Exercici 1
# *Instal·la el programa Anaconda amb Python 3, i Jupyter Notebook.*

# %% [markdown]
# ![Anaconda.png](attachment:Anaconda.png)

# %% [markdown]
# ***
# ## Exercici 2
#
# *Utilitzant Jupyter Notebook executa alguns càlculs senzills, a la vegada que et familiaritzes amb el llenguatge Markdown.*

# %%
print('Jupyter es un entorno para prograrmar en Python3')
# Out:
# Jupyter es un entorno para prograrmar en Python3

# %% [markdown]
# ***
# ## Exercici 3
# *Prova de crear títols, llistes, canviar l’estil de la lletra o afegir imatges dins del Notebook.*

# %% [markdown]
# **Estructura de los ejercicios de Nivel 1:**
#
# # Nivel 1
#
# 1. Ejercicio 1
#
# 2. Ejercicio 2
#
# 3. Ejercicio 3
#
#
# * En  ejercicio número 1 *sólo hay que instalar Anaconda para poder trabajar con el entorno de Jupyter*
#
# * En el ejercicio número 2 hay que realizar cálculos sencillos.
#
# * En el ejercicio 3 hay que crear titulos, listas, cambiar el estilo de la letra y introducir imagenes.

# %% [markdown]
# ***
#
# # Nivel 2
# *Exporta el Notebook com a pdf i com a html.*

# %% [markdown]
# **Existen dos maneras:**
#
# 1. Exportar mediante código en terminal.
#     1. Abrir terminal en Jupyter.
#     2. Escribir el codigo
#         * jupyter nbconvert Jupyter_Markdown --to pdf
#         * jupyter nbconvert Jupyter_Markdown --to htlm

# %% [markdown]
# ![Convertir%20pdf%20html.Codigo.PNG](attachment:Convertir%20pdf%20html.Codigo.PNG)

# %% [markdown]
# 2. En Jupyter File/Download as:

# %% [markdown]
# ![Download.png](attachment:Download.png)

# %% [markdown]
# ***
# # Nivell 3
# *Instal·la Nbextensions al Notebook de Jupyter.*

# %% [markdown]
# ![nbextensions.PNG](attachment:nbextensions.PNG)
